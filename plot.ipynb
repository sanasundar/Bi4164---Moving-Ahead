# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
model_labels= ["BernoulliNB", "SVC", "LinearSVC", "Neural Networks", "DecisionTreeClf", "RFC", "Markov Order=1"]
model_precision= np.array([(89.8, 89.966), (93.0, 98.29), (92.1, 93.3),(55.0, 54.0), (75.0, 100.0), (84.9, 100.0), (79.0, 79.0)])
model_precision_condense= list(model_precision[:,0])+ list(model_precision[:,1])
model_labels_condense= model_labels+ model_labels
model_hue= ["test" for i in model_labels] + ["train" for i in model_labels]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=model_labels_condense, y=model_precision_condense, hue=model_hue)
# Out:
# <Axes: >
